# %% [markdown]
# ![Insper](https://github.com/danielscarvalho/Insper-DS-Dicas/blob/master/Insper-Logo.png?raw=true)
#
# # Insper Pós-Graduação
# ## Programa Avançado em Data Science e Decisão [»](https://www.insper.edu.br/pos-graduacao/programas-avancados/programa-avancado-em-data-science-e-decisao/)

# %% [markdown]
# ## Dados imobiliários da Big Apple

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Carga de dados, pode ser demorado por conta da Internet...

# %%
dados = requests.get('https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=100').json()

# %%
len(dados)
# Out:
# 100

# %%
type(dados)
# Out:
# list

# %%
dados[0]
# Out:
# {'unique_key': '62410964',
#  'created_date': '2024-09-13T01:36:27.000',
#  'agency': 'NYPD',
#  'agency_name': 'New York City Police Department',
#  'complaint_type': 'Noise - Street/Sidewalk',
#  'descriptor': 'Loud Talking',
#  'location_type': 'Street/Sidewalk',
#  'incident_zip': '11368',
#  'incident_address': '102-01 ALSTYNE AVENUE',
#  'street_name': 'ALSTYNE AVENUE',
#  'cross_street_1': '102 STREET',
#  'cross_street_2': '103 STREET',
#  'intersection_street_1': '102 STREET',
#  'intersection_street_2': '103 STREET',
#  'address_type': 'ADDRESS',
#  'city': 'CORONA',
#  'landmark': 'ALSTYNE AVENUE',
#  'status': 'In Progress',
#  'community_board': '04 QUEENS',
#  'bbl': '4019280001',
#  'borough': 'QUEENS',
#  'x_coordinate_state_plane': '1022669',
#  'y_coordinate_state_plane': '210199',
#  'open_data_channel_type': 'MOBILE',
#  'park_facility_name': 'Unspecified',
#  'park_borough': 'QUEENS',
#  'latitude': '40.74354084657344',
#  'longitude': '-73.86135311144443',
#  'location': {'latitude': '40.74354084657344',
#   'longitude': '-73.86135311144443',
#   'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#  ':@computed_region_efsh_h5xi': '14510',
#  ':@computed_region_f5dn_yrer': '66',
#  ':@computed_region_yeji_bk3q': '3',
#  ':@computed_region_92fq_4b7q': '21',
#  ':@computed_region_sbqj_enih': '68',
#  ':@computed_region_7mpf_4k6g': '68'}

# %%
dados_df = pd.DataFrame.from_dict(dados)

# %%
dados_df.head()
# Out:
#   unique_key             created_date agency                      agency_name  \
# 0   62410964  2024-09-13T01:36:27.000   NYPD  New York City Police Department
# 1   62415367  2024-09-13T01:36:12.000   NYPD  New York City Police Department
# 2   62417006  2024-09-13T01:36:03.000   NYPD  New York City Police Department
# 3   62414099  2024-09-13T01:36:00.000   NYPD  New York City Police Department
# 4   62410483  2024-09-13T01:35:58.000   NYPD  New York City Police Department
#
#             complaint_type        descriptor               location_type  \
# 0  Noise - Street/Sidewalk      Loud Talking             Street/Sidewalk
# 1      Noise - Residential  Loud Music/Party  Residential Building/House
# 2      Noise - Residential  Loud Music/Party  Residential Building/House
# 3      Noise - Residential  Banging/Pounding  Residential Building/House
# 4               Encampment               N/A                      Subway
#
#   incident_zip       incident_address       street_name  ...  \
# 0        11368  102-01 ALSTYNE AVENUE    ALSTYNE AVENUE  ...
# 1        10466   655 EAST  230 STREET  EAST  230 STREET  ...
# 2        10466   655 EAST  230 STREET  EAST  230 STREET  ...
# 3        10458  2789 VALENTINE AVENUE  VALENTINE AVENUE  ...
# 4          NaN                    NaN               NaN  ...
#
#   :@computed_region_yeji_bk3q :@computed_region_92fq_4b7q  \
# 0                           3                          21
# 1                           5                           2
# 2                           5                           2
# 3                           5                          22
# 4                           2                          44
#
#   :@computed_region_sbqj_enih :@computed_region_7mpf_4k6g  \
# 0                          68                          68
# 1                          30                          30
# 2                          30                          30
# 3                          34                          34
# 4                          41                          41
#
#   resolution_action_updated_date bridge_highway_name bridge_highway_segment  \
# 0                            NaN                 NaN                    NaN
# 1                            NaN                 NaN                    NaN
# 2        2024-09-13T02:09:18.000                 NaN                    NaN
# 3        2024-09-13T01:51:13.000                 NaN                    NaN
# 4        2024-09-13T02:08:29.000                   R               Platform
#
#   vehicle_type resolution_description closed_date
# 0          NaN                    NaN         NaN
# 1          NaN                    NaN         NaN
# 2          NaN                    NaN         NaN
# 3          NaN                    NaN         NaN
# 4          NaN                    NaN         NaN
#
# [5 rows x 41 columns]

# %%
dados_df.head().T
# Out:
#                                                                                 0  \
# unique_key                                                               62410964
# created_date                                              2024-09-13T01:36:27.000
# agency                                                                       NYPD
# agency_name                                       New York City Police Department
# complaint_type                                            Noise - Street/Sidewalk
# descriptor                                                           Loud Talking
# location_type                                                     Street/Sidewalk
# incident_zip                                                                11368
# incident_address                                            102-01 ALSTYNE AVENUE
# street_name                                                        ALSTYNE AVENUE
# cross_street_1                                                         102 STREET
# cross_street_2                                                         103 STREET
# intersection_street_1                                                  102 STREET
# intersection_street_2                                                  103 STREET
# address_type                                                              ADDRESS
# city                                                                       CORONA
# landmark                                                           ALSTYNE AVENUE
# status                                                                In Progress
# community_board                                                         04 QUEENS
# bbl                                                                    4019280001
# borough                                                                    QUEENS
# x_coordinate_state_plane                                                  1022669
# y_coordinate_state_plane                                                   210199
# open_data_channel_type                                                     MOBILE
# park_facility_name                                                    Unspecified
# park_borough                                                               QUEENS
# latitude                                                        40.74354084657344
# longitude                                                      -73.86135311144443
# location                        {'latitude': '40.74354084657344', 'longitude':...
# :@computed_region_efsh_h5xi                                                 14510
# :@computed_region_f5dn_yrer                                                    66
# :@computed_region_yeji_bk3q                                                     3
# :@computed_region_92fq_4b7q                                                    21
# :@computed_region_sbqj_enih                                                    68
# :@computed_region_7mpf_4k6g                                                    68
# resolution_action_updated_date                                                NaN
# bridge_highway_name                                                           NaN
# bridge_highway_segment                                                        NaN
# vehicle_type                                                                  NaN
# resolution_description                                                        NaN
# closed_date                                                                   NaN
#
#                                                                                 1  \
# unique_key                                                               62415367
# created_date                                              2024-09-13T01:36:12.000
# agency                                                                       NYPD
# agency_name                                       New York City Police Department
# complaint_type                                                Noise - Residential
# descriptor                                                       Loud Music/Party
# location_type                                          Residential Building/House
# incident_zip                                                                10466
# incident_address                                             655 EAST  230 STREET
# street_name                                                      EAST  230 STREET
# cross_street_1                                                   CARPENTER AVENUE
# cross_street_2                                                      LOWERRE PLACE
# intersection_street_1                                            CARPENTER AVENUE
# intersection_street_2                                               LOWERRE PLACE
# address_type                                                              ADDRESS
# city                                                                        BRONX
# landmark                                                         EAST  230 STREET
# status                                                                In Progress
# community_board                                                          12 BRONX
# bbl                                                                    2048330028
# borough                                                                     BRONX
# x_coordinate_state_plane                                                  1022911
# y_coordinate_state_plane                                                   264242
# open_data_channel_type                                                     MOBILE
# park_facility_name                                                    Unspecified
# park_borough                                                                BRONX
# latitude                                                        40.89187241649303
# longitude                                                      -73.86016845296459
# location                        {'latitude': '40.89187241649303', 'longitude':...
# :@computed_region_efsh_h5xi                                                 11275
# :@computed_region_f5dn_yrer                                                    29
# :@computed_region_yeji_bk3q                                                     5
# :@computed_region_92fq_4b7q                                                     2
# :@computed_region_sbqj_enih                                                    30
# :@computed_region_7mpf_4k6g                                                    30
# resolution_action_updated_date                                                NaN
# bridge_highway_name                                                           NaN
# bridge_highway_segment                                                        NaN
# vehicle_type                                                                  NaN
# resolution_description                                                        NaN
# closed_date                                                                   NaN
#
#                                                                                 2  \
# unique_key                                                               62417006
# created_date                                              2024-09-13T01:36:03.000
# agency                                                                       NYPD
# agency_name                                       New York City Police Department
# complaint_type                                                Noise - Residential
# descriptor                                                       Loud Music/Party
# location_type                                          Residential Building/House
# incident_zip                                                                10466
# incident_address                                             655 EAST  230 STREET
# street_name                                                      EAST  230 STREET
# cross_street_1                                                   CARPENTER AVENUE
# cross_street_2                                                      LOWERRE PLACE
# intersection_street_1                                            CARPENTER AVENUE
# intersection_street_2                                               LOWERRE PLACE
# address_type                                                              ADDRESS
# city                                                                        BRONX
# landmark                                                         EAST  230 STREET
# status                                                                In Progress
# community_board                                                          12 BRONX
# bbl                                                                    2048330028
# borough                                                                     BRONX
# x_coordinate_state_plane                                                  1022911
# y_coordinate_state_plane                                                   264242
# open_data_channel_type                                                     MOBILE
# park_facility_name                                                    Unspecified
# park_borough                                                                BRONX
# latitude                                                        40.89187241649303
# longitude                                                      -73.86016845296459
# location                        {'latitude': '40.89187241649303', 'longitude':...
# :@computed_region_efsh_h5xi                                                 11275
# :@computed_region_f5dn_yrer                                                    29
# :@computed_region_yeji_bk3q                                                     5
# :@computed_region_92fq_4b7q                                                     2
# :@computed_region_sbqj_enih                                                    30
# :@computed_region_7mpf_4k6g                                                    30
# resolution_action_updated_date                            2024-09-13T02:09:18.000
# bridge_highway_name                                                           NaN
# bridge_highway_segment                                                        NaN
# vehicle_type                                                                  NaN
# resolution_description                                                        NaN
# closed_date                                                                   NaN
#
#                                                                                 3  \
# unique_key                                                               62414099
# created_date                                              2024-09-13T01:36:00.000
# agency                                                                       NYPD
# agency_name                                       New York City Police Department
# complaint_type                                                Noise - Residential
# descriptor                                                       Banging/Pounding
# location_type                                          Residential Building/House
# incident_zip                                                                10458
# incident_address                                            2789 VALENTINE AVENUE
# street_name                                                      VALENTINE AVENUE
# cross_street_1                                                      MIRIAM STREET
# cross_street_2                                                   EAST  197 STREET
# intersection_street_1                                               MIRIAM STREET
# intersection_street_2                                            EAST  197 STREET
# address_type                                                              ADDRESS
# city                                                                        BRONX
# landmark                                                         VALENTINE AVENUE
# status                                                                In Progress
# community_board                                                          07 BRONX
# bbl                                                                    2033040175
# borough                                                                     BRONX
# x_coordinate_state_plane                                                  1014397
# y_coordinate_state_plane                                                   255653
# open_data_channel_type                                                     ONLINE
# park_facility_name                                                    Unspecified
# park_borough                                                                BRONX
# latitude                                                       40.868331493198625
# longitude                                                      -73.89100104477686
# location                        {'latitude': '40.868331493198625', 'longitude'...
# :@computed_region_efsh_h5xi                                                 10936
# :@computed_region_f5dn_yrer                                                    24
# :@computed_region_yeji_bk3q                                                     5
# :@computed_region_92fq_4b7q                                                    22
# :@computed_region_sbqj_enih                                                    34
# :@computed_region_7mpf_4k6g                                                    34
# resolution_action_updated_date                            2024-09-13T01:51:13.000
# bridge_highway_name                                                           NaN
# bridge_highway_segment                                                        NaN
# vehicle_type                                                                  NaN
# resolution_description                                                        NaN
# closed_date                                                                   NaN
#
#                                                                                 4
# unique_key                                                               62410483
# created_date                                              2024-09-13T01:35:58.000
# agency                                                                       NYPD
# agency_name                                       New York City Police Department
# complaint_type                                                         Encampment
# descriptor                                                                    N/A
# location_type                                                              Subway
# incident_zip                                                                  NaN
# incident_address                                                              NaN
# street_name                                                                   NaN
# cross_street_1                                                                NaN
# cross_street_2                                                                NaN
# intersection_street_1                                                         NaN
# intersection_street_2                                                         NaN
# address_type                                                                  NaN
# city                                                                          NaN
# landmark                                                                      NaN
# status                                                                In Progress
# community_board                                              Unspecified BROOKLYN
# bbl                                                                           NaN
# borough                                                                  BROOKLYN
# x_coordinate_state_plane                                                   977761
# y_coordinate_state_plane                                                   170612
# open_data_channel_type                                                     MOBILE
# park_facility_name                                                    Unspecified
# park_borough                                                             BROOKLYN
# latitude                                                       40.634964726370036
# longitude                                                      -74.02337946048613
# location                        {'latitude': '40.634964726370036', 'longitude'...
# :@computed_region_efsh_h5xi                                                 18180
# :@computed_region_f5dn_yrer                                                    10
# :@computed_region_yeji_bk3q                                                     2
# :@computed_region_92fq_4b7q                                                    44
# :@computed_region_sbqj_enih                                                    41
# :@computed_region_7mpf_4k6g                                                    41
# resolution_action_updated_date                            2024-09-13T02:08:29.000
# bridge_highway_name                                                             R
# bridge_highway_segment                                                   Platform
# vehicle_type                                                                  NaN
# resolution_description                                                        NaN
# closed_date                                                                   NaN

# %%
dados_df.memory_usage()
# Out:
# Index                             132
# unique_key                        800
# created_date                      800
# agency                            800
# agency_name                       800
# complaint_type                    800
# descriptor                        800
# location_type                     800
# incident_zip                      800
# incident_address                  800
# street_name                       800
# cross_street_1                    800
# cross_street_2                    800
# intersection_street_1             800
# intersection_street_2             800
# address_type                      800
# city                              800
# landmark                          800
# status                            800
# community_board                   800
# bbl                               800
# borough                           800
# x_coordinate_state_plane          800
# y_coordinate_state_plane          800
# open_data_channel_type            800
# park_facility_name                800
# park_borough                      800
# latitude                          800
# longitude                         800
# location                          800
# :@computed_region_efsh_h5xi       800
# :@computed_region_f5dn_yrer       800
# :@computed_region_yeji_bk3q       800
# :@computed_region_92fq_4b7q       800
# :@computed_region_sbqj_enih       800
# :@computed_region_7mpf_4k6g       800
# resolution_action_updated_date    800
# bridge_highway_name               800
# bridge_highway_segment            800
# vehicle_type                      800
# resolution_description            800
# closed_date                       800
# dtype: int64

# %%
dados_df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      100 non-null    object
#  1   created_date                    100 non-null    object
#  2   agency                          100 non-null    object
#  3   agency_name                     100 non-null    object
#  4   complaint_type                  100 non-null    object
#  5   descriptor                      100 non-null    object
#  6   location_type                   100 non-null    object
#  7   incident_zip                    98 non-null     object
#  8   incident_address                98 non-null     object
#  9   street_name                     98 non-null     object
#  10  cross_street_1                  97 non-null     object
#  11  cross_street_2                  98 non-null     object
#  12  intersection_street_1           97 non-null     object
#  13  intersection_street_2           98 non-null     object
#  14  address_type                    99 non-null     object
#  15  city                            98 non-null     object
#  16  landmark                        98 non-null     object
#  17  status                          100 non-null    object
#  18  community_board                 100 non-null    object
#  19  bbl                             89 non-null     object
#  20  borough                         100 non-null    object
#  21  x_coordinate_state_plane        100 non-null    object
#  22  y_coordinate_state_plane        100 non-null    object
#  23  open_data_channel_type          100 non-null    object
#  24  park_facility_name              100 non-null    object
#  25  park_borough                    100 non-null    object
#  26  latitude                        100 non-null    object
#  27  longitude                       100 non-null    object
#  28  location                        100 non-null    object
#  29  :@computed_region_efsh_h5xi     100 non-null    object
#  30  :@computed_region_f5dn_yrer     100 non-null    object
#  31  :@computed_region_yeji_bk3q     100 non-null    object
#  32  :@computed_region_92fq_4b7q     100 non-null    object
#  33  :@computed_region_sbqj_enih     100 non-null    object
#  34  :@computed_region_7mpf_4k6g     100 non-null    object
#  35  resolution_action_updated_date  33 non-null     object
#  36  bridge_highway_name             2 non-null      object
#  37  bridge_highway_segment          2 non-null      object
#  38  vehicle_type                    3 non-null      object
#  39  resolution_description          8 non-null      object
#  40  closed_date                     6 non-null      object
# dtypes: object(41)
# memory usage: 237.6 KB

# %% [markdown]
# Volume de dados maior, o describe também pode demorar...

# %%
dados_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      100 non-null    object
#  1   created_date                    100 non-null    object
#  2   agency                          100 non-null    object
#  3   agency_name                     100 non-null    object
#  4   complaint_type                  100 non-null    object
#  5   descriptor                      100 non-null    object
#  6   location_type                   100 non-null    object
#  7   incident_zip                    98 non-null     object
#  8   incident_address                98 non-null     object
#  9   street_name                     98 non-null     object
#  10  cross_street_1                  97 non-null     object
#  11  cross_street_2                  98 non-null     object
#  12  intersection_street_1           97 non-null     object
#  13  intersection_street_2           98 non-null     object
#  14  address_type                    99 non-null     object
#  15  city                            98 non-null     object
#  16  landmark                        98 non-null     object
#  17  status                          100 non-null    object
#  18  community_board                 100 non-null    object
#  19  bbl                             89 non-null     object
#  20  borough                         100 non-null    object
#  21  x_coordinate_state_plane        100 non-null    object
#  22  y_coordinate_state_plane        100 non-null    object
#  23  open_data_channel_type          100 non-null    object
#  24  park_facility_name              100 non-null    object
#  25  park_borough                    100 non-null    object
#  26  latitude                        100 non-null    object
#  27  longitude                       100 non-null    object
#  28  location                        100 non-null    object
#  29  :@computed_region_efsh_h5xi     100 non-null    object
#  30  :@computed_region_f5dn_yrer     100 non-null    object
#  31  :@computed_region_yeji_bk3q     100 non-null    object
#  32  :@computed_region_92fq_4b7q     100 non-null    object
#  33  :@computed_region_sbqj_enih     100 non-null    object
#  34  :@computed_region_7mpf_4k6g     100 non-null    object
#  35  resolution_action_updated_date  33 non-null     object
#  36  bridge_highway_name             2 non-null      object
#  37  bridge_highway_segment          2 non-null      object
#  38  vehicle_type                    3 non-null      object
#  39  resolution_description          8 non-null      object
#  40  closed_date                     6 non-null      object
# dtypes: object(41)
# memory usage: 32.2+ KB

# %%
compliant_counts = dados_df['complaint_type'].value_counts()

# %%
compliant_counts[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='complaint_type'>

# %% [markdown]
# Para saber mais:
#
# https://ny.curbed.com/2018/1/3/16845686/weather-nyc-311-heat-hot-water-complaint

# %% [markdown]
# ### Pandas Profiling

# %% [markdown]
# Uma análise preliminar de dados pode ser realizada de forma automatizada.
#
# Todas as colunas do data frame são analisadas e é gerado um relatório em HTML, diversos tipos de análises são feitas.
#
# Vamos testar com o arquivo de dados de consumo elétrico.

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (3.8.4)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (2.5.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (2.1.3)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (1.26.4)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.4-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (4.66.4)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\helio\anaconda3\lib\site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\helio\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\helio\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.2.1)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: Pillow in c:\users\helio\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\helio\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\helio\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\helio\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\helio\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\helio\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\helio\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\helio\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\helio\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\helio\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\helio\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\helio\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\helio\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\helio\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\helio\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\helio\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\helio\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\helio\appdata\roaming\python\python312\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\helio\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\helio\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.5.0)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    -------------- ------------------------- 92.2/262.6 kB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 262.6/262.6 kB 5.4 MB/s eta 0:00:00
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#     --------------------------------------- 0.1/4.7 MB 6.8 MB/s eta 0:00:01
#    - -------------------------------------- 0.2/4.7 MB 2.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.5/4.7 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.6/4.7 MB 4.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.9/4.7 MB 4.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.2/4.7 MB 5.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.4/4.7 MB 6.0 MB/s eta 0:00:01
#    -------------- ------------------------- 1.7/4.7 MB 6.2 MB/s eta 0:00:01
#    --------------- ------------------------ 1.9/4.7 MB 5.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.1/4.7 MB 6.0 MB/s eta 0:00:01
#    -------------------- ------------------- 2.4/4.7 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.7/4.7 MB 6.3 MB/s eta 0:00:01
#    ------------------------ --------------- 2.9/4.7 MB 6.2 MB/s eta 0:00:01
#    -------------------------- ------------- 3.1/4.7 MB 6.4 MB/s eta 0:00:01
#    --------------------------- ------------ 3.3/4.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.3/4.7 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.4/4.7 MB 5.8 MB/s eta 0:00:01
#    ------------------------------ --------- 3.6/4.7 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.9/4.7 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.0/4.7 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 4.4/4.7 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 5.7 MB/s eta 0:00:00
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 6.1 MB/s eta 0:00:00
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#    ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#    ----------------------- ---------------- 184.3/309.8 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 309.8/309.8 kB 6.4 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp312-cp312-win_amd64.whl (666 kB)
#    ---------------------------------------- 0.0/666.4 kB ? eta -:--:--
#    ------------- -------------------------- 225.3/666.4 kB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 512.0/666.4 kB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 666.4/666.4 kB 7.1 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#    --------------------------------- ----- 256.0/296.5 kB 16.4 MB/s eta 0:00:01
#    --------------------------------------- 296.5/296.5 kB 19.1 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27092 sha256=c553f01141b2626c91d1d2291b2932874a872f7da2c0bbad0a216af4d265e0a0
#   Stored in directory: c:\users\helio\appdata\local\pip\cache\wheels\5f\d4\d7\4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, multimethod, joblib, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 joblib-1.1.1 missingno-0.5.2 multimethod-1.12 pandas-profiling-3.2.0 phik-0.12.4 tangled-up-in-unicode-0.2.0 visions-0.7.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.4.2 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.

# %%
eletrico_df = pd.read_csv("consumo_eletrico_SP_2015_2019.csv", encoding='latin-1', delimiter=';')

# %%
eletrico_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3225 entries, 0 to 3224
# Data columns (total 9 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Localidades                                                                     3225 non-null   object
#  1   Períodos                                                                        3225 non-null   int64
#  2   Consumo de Energia Elétrica - Total (Em MWh)                                    3225 non-null   int64
#  3   Consumo de Energia Elétrica -  Comércio e Serviços (Em MWh)                     3225 non-null   int64
#  4   Consumo de Energia Elétrica - Industrial (Em MWh)                               3225 non-null   object
#  5   Consumo de Energia Elétrica - Residencial (Em MWh)                              3225 non-null   int64
#  6   Consumo de Energia Elétrica - Rural (Em MWh)                                    3225 non-null   object
#  7   Consumo de Energia Elétrica - Iluminação e Serviços Públicos e Outros (Em MWh)  3225 non-null   int64
#  8   Cód. IBGE                                                                       3225 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 226.9+ KB

# %%
eletrico_df.describe()
# Out:
#           Períodos  Consumo de Energia Elétrica - Total (Em MWh)  \
# count  3225.000000                                  3.225000e+03
# mean   2017.000000                                  2.023347e+05
# std       1.414433                                  1.152760e+06
# min    2015.000000                                  1.396000e+03
# 25%    2016.000000                                  9.650000e+03
# 50%    2017.000000                                  2.551300e+04
# 75%    2018.000000                                  1.018630e+05
# max    2019.000000                                  2.850518e+07
#
#        Consumo de Energia Elétrica -  Comércio e Serviços (Em MWh)  \
# count                                       3.225000e+03
# mean                                        4.452873e+04
# std                                         4.314013e+05
# min                                         4.700000e+01
# 25%                                         1.095000e+03
# 50%                                         3.335000e+03
# 75%                                         1.492300e+04
# max                                         1.141325e+07
#
#        Consumo de Energia Elétrica - Residencial (Em MWh)  \
# count                                       3.225000e+03
# mean                                        6.072539e+04
# std                                         4.441853e+05
# min                                         5.190000e+02
# 25%                                         3.562000e+03
# 50%                                         9.313000e+03
# 75%                                         3.248200e+04
# max                                         1.123174e+07
#
#        Consumo de Energia Elétrica - Iluminação e Serviços Públicos e Outros (Em MWh)  \
# count                                       3.225000e+03
# mean                                        1.794097e+04
# std                                         1.228592e+05
# min                                         3.140000e+02
# 25%                                         1.329000e+03
# 50%                                         3.161000e+03
# 75%                                         1.015700e+04
# max                                         3.185120e+06
#
#           Cód. IBGE
# count  3.225000e+03
# mean   3.528698e+06
# std    1.668996e+04
# min    3.500105e+06
# 25%    3.514601e+06
# 50%    3.528700e+06
# 75%    3.543204e+06
# max    3.557303e+06

# %%
eletrico_df
# Out:
#      Localidades  Períodos  Consumo de Energia Elétrica - Total (Em MWh)  \
# 0     Adamantina      2015                                         69599
# 1     Adamantina      2016                                         70433
# 2     Adamantina      2017                                         72659
# 3     Adamantina      2018                                         74776
# 4     Adamantina      2019                                         79010
# ...          ...       ...                                           ...
# 3220    Zacarias      2015                                          5797
# 3221    Zacarias      2016                                          5607
# 3222    Zacarias      2017                                          6438
# 3223    Zacarias      2018                                          6818
# 3224    Zacarias      2019                                          7695
#
#       Consumo de Energia Elétrica -  Comércio e Serviços (Em MWh)  \
# 0                                                 16012
# 1                                                 16808
# 2                                                 18228
# 3                                                 18478
# 4                                                 19475
# ...                                                 ...
# 3220                                                510
# 3221                                                486
# 3222                                                502
# 3223                                                540
# 3224                                                631
#
#      Consumo de Energia Elétrica - Industrial (Em MWh)  \
# 0                                                 8068
# 1                                                 6960
# 2                                                 7474
# 3                                                 8108
# 4                                                 8958
# ...                                                ...
# 3220                                               637
# 3221                                               611
# 3222                                               656
# 3223                                               651
# 3224                                               732
#
#       Consumo de Energia Elétrica - Residencial (Em MWh)  \
# 0                                                 30007
# 1                                                 31062
# 2                                                 31935
# 3                                                 32848
# 4                                                 35115
# ...                                                 ...
# 3220                                               2048
# 3221                                               2016
# 3222                                               2280
# 3223                                               2351
# 3224                                               2568
#
#      Consumo de Energia Elétrica - Rural (Em MWh)  \
# 0                                            2779
# 1                                            2767
# 2                                            2724
# 3                                            2901
# 4                                            3070
# ...                                           ...
# 3220                                         1735
# 3221                                         1668
# 3222                                         2106
# 3223                                         2392
# 3224                                         2771
#
#       Consumo de Energia Elétrica - Iluminação e Serviços Públicos e Outros (Em MWh)  \
# 0                                                 12732
# 1                                                 12836
# 2                                                 12299
# 3                                                 12441
# 4                                                 12393
# ...                                                 ...
# 3220                                                867
# 3221                                                826
# 3222                                                894
# 3223                                                884
# 3224                                                993
#
#       Cód. IBGE
# 0       3500105
# 1       3500105
# 2       3500105
# 3       3500105
# 4       3500105
# ...         ...
# 3220    3557154
# 3221    3557154
# 3222    3557154
# 3223    3557154
# 3224    3557154
#
# [3225 rows x 9 columns]

# %%
import numpy as np
import pandas as pd

from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 4
#       1 import numpy as np
#       2 import pandas as pd
# ----> 4 from pandas_profiling import ProfileReport
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\pandas_profiling\profile_report.py:11
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\__init__.py:4
#       1 """Core functionality"""
#       3 from visions import types, typesets, utils
# ----> 4 from visions.backends import *
#       5 from visions.declarative import create_type
#       6 from visions.functional import (
#       7     cast_to_detected,
#       8     cast_to_inferred,
#       9     detect_type,
#      10     infer_type,
#      11 )
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\backends\__init__.py:9
#       6 try:
#       7     import pandas as pd
# ----> 9     import visions.backends.pandas
#      10     from visions.backends.pandas.test_utils import pandas_version
#      12     if pandas_version[0] < 1:
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\backends\pandas\__init__.py:2
#       1 import visions.backends.pandas.traversal
# ----> 2 import visions.backends.pandas.types
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\backends\pandas\types\__init__.py:3
#       1 import visions.backends.pandas.types.boolean
#       2 import visions.backends.pandas.types.categorical
# ----> 3 import visions.backends.pandas.types.complex
#       4 import visions.backends.pandas.types.count
#       5 import visions.backends.pandas.types.date
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\backends\pandas\types\complex.py:7
#       5 from visions.backends.pandas.series_utils import series_not_empty, series_not_sparse
#       6 from visions.backends.pandas.types.float import string_is_float
# ----> 7 from visions.backends.shared.parallelization_engines import pandas_apply
#       8 from visions.types.complex import Complex
#       9 from visions.types.string import String
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\backends\shared\__init__.py:1
# ----> 1 from . import nan_handling, parallelization_engines, utilities
#
# File c:\Users\Helio\anaconda3\Lib\site-packages\visions\backends\shared\nan_handling.py:34
#      30 # TODO: There are optimizations here, just have to define precisely the desired missing ruleset in the
#      31 # generated jit
#      32 if has_numba:
# ---> 34     @nb.generated_jit(nopython=True)
#      35     def is_missing(x):
#      36         """
#      37         Return True if the value is missing, False otherwise.
#      38         """
#      39         if isinstance(x, nb.types.Float):
#
# AttributeError: module 'numba' has no attribute 'generated_jit'

# %%
profile = ProfileReport(eletrico_df, title='Pandas Profiling Report - Insper')

# %%
profile.to_file(output_file="eletrico_profile_Insper_v2.html")

# %%
# %%html
#
# <iframe src="eletrico_profile_Insper_v2.html" width="100%" height="800px"></iframe>

# %% [markdown]
# ### Atividade extra
#
# Gerar o Pandas Profiling com os dados do projeto integrador

# %% [markdown]
# Para saber mais vejam o site do pandas-profiling:
#
# https://github.com/pandas-profiling/pandas-profiling

# %% [markdown]
# Dicas de Data Science no GitHub:
#
# https://github.com/danielscarvalho/Insper-DS-Dicas
